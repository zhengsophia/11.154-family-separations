# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# %%
# removed first row and column
# df = pd.read_csv ("/Users/kellyfang/Downloads/11.154/separation_data_set.csv")
df = pd.read_csv ("separation_data_set.csv")
df["lat"] = ""
df["lon"] = ""

display(df)
# Out:
#      AGE GENDER          COO DATE_APPREHENDED REFERRAL_DATE DATE_ORR_APPROVED  \
# 0     16      M       Brazil        2/15/2018     2/15/2018         2/17/2018
# 1     17      F      Romania        5/27/2018     5/29/2018         5/30/2018
# 2     11      M       Mexico         2/1/2018      2/6/2018          2/8/2018
# 3     15      M       Mexico         2/2/2018      2/6/2018          2/8/2018
# 4      8      M     Honduras         6/2/2018      6/4/2018          6/5/2018
# ...   ..    ...          ...              ...           ...               ...
# 3165  14      M    Guatemala        1/28/2019     1/30/2019          2/1/2019
# 3166  17      M    Guatemala        1/14/2019     1/16/2019         1/16/2019
# 3167   1      F  El Salvador       12/10/2018    12/12/2018        12/14/2018
# 3168  16      M    Guatemala        12/6/2018      1/2/2019          1/3/2019
# 3169   9      M    Guatemala       12/16/2018    12/19/2018        12/22/2018
#
#         REFERRING OFFICE                    FACILITY_APPROVED  \
# 0         El Paso  (ELP)          Heartland Intl Childrens RC
# 1        Harlingen (SNA)                            Homestead
# 2       San Diego  (SND)                       Cayuga Centers
# 3       San Diego  (SND)                       Cayuga Centers
# 4                    NaN                       Cayuga Centers
# ...                  ...                                  ...
# 3165      El Paso  (ELP)                            Homestead
# 3166     Harlingen (SNA)             Southwest Key Casa Padre
# 3167  Phoenix, AZ  (PHO)  Bethany Christian Services Maryland
# 3168    San Diego  (SND)              Southwest Key San Diego
# 3169  Phoenix, AZ  (PHO)                    BCFS Raymondville
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0     Discharged Under other approp circumstances  DISCHARGED        7/8/2018
# 1     Discharged Under other approp circumstances  DISCHARGED        6/4/2018
# 2     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 3     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 4     Discharged Under other approp circumstances  DISCHARGED       11/7/2018
# ...                                           ...         ...             ...
# 3165                                Still In Care    ADMITTED             NaN
# 3166                  Other approp. Circumstances  DISCHARGED       3/21/2019
# 3167                    Reunited with Sep. Parent  DISCHARGED       3/15/2019
# 3168                    Reunited with Sep. Parent  DISCHARGED        1/8/2019
# 3169                                Still In Care    ADMITTED             NaN
#
#                           Reason fo Separation lat lon
# 0                        Zero Tolerance Policy
# 1                        Zero Tolerance Policy
# 2                        Zero Tolerance Policy
# 3                        Zero Tolerance Policy
# 4                        Zero Tolerance Policy
# ...                                        ...  ..  ..
# 3165                   Parent Criminal History
# 3166                   Parent Criminal History
# 3167                                     Other
# 3168                     Adult Relative‐ Other
# 3169  Unable to verify familial\nrelationship.
#
# [3170 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['AGE', 'GENDER', 'COO', 'DATE_APPREHENDED', 'REFERRAL_DATE',
#        'DATE_ORR_APPROVED', 'REFERRING OFFICE', 'FACILITY_APPROVED',
#        'REUNITIED_SEP_PARENTS', 'UAC STATUS', 'Date Discharged',
#        'Reason fo Separation', 'lat', 'lon'],
#       dtype='object')

# %%
facilities_df = df.groupby(by=["FACILITY_APPROVED"]).size().to_frame('count').reset_index()
display(facilities_df)
# Out:
#                 FACILITY_APPROVED  count
# 0   A New Leaf – Dorothy Mitchell      5
# 1           A New Leaf – Peterson      5
# 2            Abbott House Shelter     26
# 3                Abbott House TFC      3
# 4                    BCFS Baytown     62
# ..                            ...    ...
# 95                    St. PJs TFC     15
# 96                   The Villages     14
# 97                        Upbring     35
# 98             Youth For Tomorrow     22
# 99                      Youthcare      8
#
# [100 rows x 2 columns]

# %%
df['FACILITY_APPROVED'].unique()
# Out:
# array(['Heartland Intl Childrens RC', 'Homestead', 'Cayuga Centers',
#        'Southwest Key Las Palmas', 'Southwest Key Campbell',
#        'Southwest Key Casa Padre', 'A New Leaf – Dorothy Mitchell',
#        'Southwest Key Sol', 'Southwest Key Casa Kokopelli',
#        'Southwest Key Estrella', 'The Villages', 'A New Leaf – Peterson',
#        'Heartland Guadalupe', 'BCFS San Antonio TFC', 'Morrison Downtown',
#        'Southwest Key Mesa Shelter', 'LSS of New York TFC',
#        'Board of Child Care TFC', 'Bethany Christian Services TFC',
#        'Leake and Watts TFC', 'Nuevo Amanecer LCS', 'Bokenkamp TFC',
#        'Southwest Key Casa Phoenix', 'BCFS Extended Care',
#        'BCFS Chavaneaux', 'H', 'Southwest Key Canutillo', 'His House',
#        'Catholic Charities Boystown', 'International Christian Adoptions',
#        'Southwest Key Antigua', 'St. PJs Childrens Home',
#        'Southwest Key Casa Montezuma', 'Southwest Key Conroe',
#        'Southwest Key El Presidente', 'Southwest Key Combes',
#        'Heartland CHAP', 'Shiloh Treatment Center',
#        'Southwest Key Rio Grande', 'Bethany Christian Services Shelter',
#        'Youth For Tomorrow', 'Catholic Guardian Services TFC',
#        'Childrens Village Shelter', 'Southwest Key Casa Lighthouse',
#        'MercyFirst', 'Bethany Christian Services Maryland',
#        'BCFS Baytown', 'CC Houston', 'David and Margaret',
#        'Southwest Key Nueva Esperanza', 'Holy Family Institute',
#        'Southwest Key Casa Quetzal', 'Abbott House Shelter',
#        'Rite of Passage ‐ Sycamore', 'KidsPeace', 'Crittenton Shelter',
#        'Southwest Key Glendale', 'LSS of New York',
#        'Heartland Intl Childrens Center', 'Bokenkamp',
#        'Rite of Passage ‐ Canyon', 'LSSS New Hope',
#        'Southwest Key San Diego', 'Board of Child Care Shelter', 'Noank',
#        'BCFS Harlingen', 'SWK Processing Center', 'BCFS Raymondville',
#        'Upbring', 'Childrens Home of Kingston',
#        'Southwest Key Casita Del Valle', 'Southwest Key Casa Franklin',
#        'Southwest Key Casa Houston', 'Catholic Guardian Services Crotona',
#        'Center for Family Services Shelter', 'CC Fort Worth Shelter',
#        'BCFS San Antonio', 'LSS Carolinas TFC', 'Leake and Watts',
#        'Southwest Key Casa Blanca', 'BCFS Fairfield', 'JCCA',
#        'Lincoln Hall Boys Haven', 'Maryville Academy', 'St. PJs TFC',
#        'Youthcare', 'Seton Home', 'Southwest Key Pleasant Hill',
#        'Catholic Guardian Services', 'IES Brownsville', 'IES Los Fresnos',
#        'IES Harlingen', 'David and Margaret LTFC', 'CHSI San Benito',
#        'BCFS Driscoll', 'CHSI Los Fresnos', 'BCFS Tornillo',
#        'CC Fort Worth TFC', 'CHSI Casa Norma Linda', 'Abbott House TFC'],
#       dtype=object)

# %%
shelter_dict = {
    'Heartland Intl Childrens RC' : (41.889183, -87.632519),
    'Cayuga Centers' : (40.8088, 73.9307),
    'Homestead' : (0,0),
    'Southwest Key Las Palmas' : (33.434662, -111.840591),
    'Southwest Key Campbell' : (33.501260, -112.115390),
    'Southwest Key Casa Padre' : (25.943220, -97.424080),
    'A New Leaf – Dorothy Mitchell': (33.422445245202574, -111.7948833962709),
    'Southwest Key Sol': (0,0),
    'Southwest Key Casa Kokopelli' : (33.41057000348104, -111.81485200053244),
    'Southwest Key Estrella' :(0,0),
    'The Villages' : (0,0),
    'A New Leaf – Peterson' : (33.422445245202574, -111.7948833962709),
    'Heartland Guadalupe' :(0,0), 
    'BCFS San Antonio TFC' :(29.489023513806092, -98.5685671455097),
    'Morrison Downtown' :(45.55889871413686, -122.5491566354091),
    'Southwest Key Mesa Shelter': (0,0), 
    'LSS of New York TFC' :(40.81396993020305, -73.9664686138336),
    'Board of Child Care TFC': (38.49329657584188, -76.7675310422091), 
    'Bethany Christian Services TFC': (0,0),
    'Leake and Watts TFC':(40.84803859001925, -73.84726123279286),
    'Nuevo Amanecer LCS':(34.28755910934501, -118.43619217796676), 
    'Bokenkamp TFC':(27.7177065686254, -97.34968717809491),
    'Southwest Key Casa Phoenix':(0,0), 
    'BCFS Extended Care':(0,0),
    'BCFS Chavaneaux':(29.321531760534477, -98.52796822690473),
    'H':(0,0), 
    'Southwest Key Canutillo':(31.90807037763406, -106.59511040483042),
    'His House':(25.956392771561816, -80.27980225773756),
    'Catholic Charities Boystown':(26.160271563841256, -80.12750692556861), 
    'International Christian Adoptions':(33.51632724911393, -117.16524905777466),
    'Southwest Key Antigua':(0,0),
    'St. PJs Childrens Home':(29.389510605840876, -98.49270134222061),
    'Southwest Key Casa Montezuma': (0,0),
    'Southwest Key Conroe':(0,0),
    'Southwest Key El Presidente':(0,0), 
    'Southwest Key Combes':(0,0),
    'Heartland CHAP':(0,0), 
    'Shiloh Treatment Center':(29.519127294074426, -95.35235029118338),
    'Southwest Key Rio Grande':(0,0), 
    'Bethany Christian Services Shelter':(0,0),
    'Youth For Tomorrow':(38.73978262834332, -77.54913090432463),
    'Catholic Guardian Services TFC':(40.758022803328025, -73.96387644917374),
    'Childrens Village Shelter':(40.86712278967711, -73.89302256434361), 
    'Southwest Key Casa Lighthouse':(0,0),
    'MercyFirst':(40.82190315799205, -73.48837767356392),
    'Bethany Christian Services Maryland':(38.98937137244992, -76.69293258909268),
    'BCFS Baytown':(29.784162841517396, -95.05649672675278),
    'CC Houston':(0,0),
    'David and Margaret':(34.10225098905935, -117.78497742673066),
    'Southwest Key Nueva Esperanza':(26.022101482987534, -97.4265115439823), 
    'Holy Family Institute':(40.51085747804056, -80.0988190796778),
    'Southwest Key Casa Quetzal':(0,0),
    'Abbott House Shelter':(41.04431838970179, -73.85901607353021),
    'Rite of Passage ‐ Sycamore':(39.023582198094, -119.74986872612035), 
    'KidsPeace':(40.596270487855485, -75.40668221092272),
    'Crittenton Shelter':(0,0),
    'Southwest Key Glendale':(0,0),
    'LSS of New York':(40.81083639084717, -73.96400573997549),
    'Heartland Intl Childrens Center':(41.88621532425004, -87.62569283046726),
    'Bokenkamp':(27.71790130420733, -97.34967108875165),
    'Rite of Passage ‐ Canyon':(0,0), 
    'LSSS New Hope':(26.210123491244904, -98.21048473254535),
    'Southwest Key San Diego': (0,0), 
    'Board of Child Care Shelter':(39.346900872776, -76.76049583255488), 
    'Noank':(41.35492631454048, -72.08294644215162),
    'BCFS Harlingen': (26.190327116846483, -97.6776081421415),
    'SWK Processing Center':(0,0), 
    'BCFS Raymondville':(26.451811397813433, -97.79827777339452),
    'Upbring':(29.672295654739035, -98.50256852879197), 
    'Childrens Home of Kingston':(41.92485519650927, -73.97117177341138),
    'Southwest Key Casita Del Valle':(0,0),
    'Southwest Key Casa Franklin':(0,0),
    'Southwest Key Casa Houston':(0,0),
    'Catholic Guardian Services Crotona':(40.85313762030175, -73.88384835892722),
    'Center for Family Services Shelter':(39.94073661213475, -75.11795520203565),
    'CC Fort Worth Shelter':(32.68354219483105, -97.32727386355151),
    'BCFS San Antonio':(29.489017, -98.568533), 
    'LSS Carolinas TFC':(35.653487891677926, -80.48559843567813),
    'Leake and Watts': (40.84803859001925, -73.84726123279286),
    'Southwest Key Casa Blanca':(0,0), 
    'BCFS Fairfield':(38.27196592144918, -122.05016687950611), 
    'JCCA':(41.129272265170066, -73.77766517339191),
    'Lincoln Hall Boys Haven':(41.3201108125575, -73.72065523631649), 
    'Maryville Academy': (42.06716651238874, -87.89736113623661),
    'St. PJs TFC':(29.38916001522818, -98.49268524637117),
    'Youthcare':(47.66829272090686, -122.2998400444896), 
    'Seton Home':(29.38871764021308, -98.49104224214504), 
    'Southwest Key Pleasant Hill':(29.38871764021308, -98.49104224214504),
    'Catholic Guardian Services':(40.880516052246094, -73.89922332763672),
    'IES Brownsville':(26.0718647, 97.4763276), 
    'IES Los Fresnos':(26.07855987548828, -97.47564697265625),
    'IES Harlingen':(26.184149965124526, -97.73859872658379), 
    'David and Margaret LTFC':(34.104237, 117.784864), 
    'CHSI San Benito':(26.132187, -97.628685),
    'BCFS Driscoll':(27.789972, -97.654548), 
    'CHSI Los Fresnos': (26.129432678222656, -97.47114562988281), 
    'BCFS Tornillo': (31.464328, -106.169116),
    'CC Fort Worth TFC':(40.741895, -73.989308), 
    'CHSI Casa Norma Linda':(26.075903730505722, -97.52940599545984),
    'Abbott House TFC':(41.04393398947575, -73.85895706051566)
    
}

for shelter in shelter_dict.keys():
    print(shelter)
    df.loc[df['FACILITY_APPROVED'] == shelter, 'lat'] = shelter_dict[shelter][0]
    df.loc[df['FACILITY_APPROVED'] == shelter, 'lon'] = shelter_dict[shelter][1]

display(df)
# Out:
# Heartland Intl Childrens RC
# Cayuga Centers
# Homestead
# Southwest Key Las Palmas
# Southwest Key Campbell
# Southwest Key Casa Padre
# A New Leaf – Dorothy Mitchell
# Southwest Key Sol
# Southwest Key Casa Kokopelli
# Southwest Key Estrella
# The Villages
# A New Leaf – Peterson
# Heartland Guadalupe
# BCFS San Antonio TFC
# Morrison Downtown
# Southwest Key Mesa Shelter
# LSS of New York TFC
# Board of Child Care TFC
# Bethany Christian Services TFC
# Leake and Watts TFC
# Nuevo Amanecer LCS
# Bokenkamp TFC
# Southwest Key Casa Phoenix
# BCFS Extended Care
# BCFS Chavaneaux
# H
# Southwest Key Canutillo
# His House
# Catholic Charities Boystown
# International Christian Adoptions
# Southwest Key Antigua
# St. PJs Childrens Home
# Southwest Key Casa Montezuma
# Southwest Key Conroe
# Southwest Key El Presidente
# Southwest Key Combes
# Heartland CHAP
# Shiloh Treatment Center
# Southwest Key Rio Grande
# Bethany Christian Services Shelter
# Youth For Tomorrow
# Catholic Guardian Services TFC
# Childrens Village Shelter
# Southwest Key Casa Lighthouse
# MercyFirst
# Bethany Christian Services Maryland
# BCFS Baytown
# CC Houston
# David and Margaret
# Southwest Key Nueva Esperanza
# Holy Family Institute
# Southwest Key Casa Quetzal
# Abbott House Shelter
# Rite of Passage ‐ Sycamore
# KidsPeace
# Crittenton Shelter
# Southwest Key Glendale
# LSS of New York
# Heartland Intl Childrens Center
# Bokenkamp
# Rite of Passage ‐ Canyon
# LSSS New Hope
# Southwest Key San Diego
# Board of Child Care Shelter
# Noank
# BCFS Harlingen
# SWK Processing Center
# BCFS Raymondville
# Upbring
# Childrens Home of Kingston
# Southwest Key Casita Del Valle
# Southwest Key Casa Franklin
# Southwest Key Casa Houston
# Catholic Guardian Services Crotona
# Center for Family Services Shelter
# CC Fort Worth Shelter
# BCFS San Antonio
# LSS Carolinas TFC
# Leake and Watts
# Southwest Key Casa Blanca
# BCFS Fairfield
# JCCA
# Lincoln Hall Boys Haven
# Maryville Academy
# St. PJs TFC
# Youthcare
# Seton Home
# Southwest Key Pleasant Hill
# Catholic Guardian Services
# IES Brownsville
# IES Los Fresnos
# IES Harlingen
# David and Margaret LTFC
# CHSI San Benito
# BCFS Driscoll
# CHSI Los Fresnos
# BCFS Tornillo
# CC Fort Worth TFC
# CHSI Casa Norma Linda
# Abbott House TFC
#      AGE GENDER          COO DATE_APPREHENDED REFERRAL_DATE DATE_ORR_APPROVED  \
# 0     16      M       Brazil        2/15/2018     2/15/2018         2/17/2018
# 1     17      F      Romania        5/27/2018     5/29/2018         5/30/2018
# 2     11      M       Mexico         2/1/2018      2/6/2018          2/8/2018
# 3     15      M       Mexico         2/2/2018      2/6/2018          2/8/2018
# 4      8      M     Honduras         6/2/2018      6/4/2018          6/5/2018
# ...   ..    ...          ...              ...           ...               ...
# 3165  14      M    Guatemala        1/28/2019     1/30/2019          2/1/2019
# 3166  17      M    Guatemala        1/14/2019     1/16/2019         1/16/2019
# 3167   1      F  El Salvador       12/10/2018    12/12/2018        12/14/2018
# 3168  16      M    Guatemala        12/6/2018      1/2/2019          1/3/2019
# 3169   9      M    Guatemala       12/16/2018    12/19/2018        12/22/2018
#
#         REFERRING OFFICE                    FACILITY_APPROVED  \
# 0         El Paso  (ELP)          Heartland Intl Childrens RC
# 1        Harlingen (SNA)                            Homestead
# 2       San Diego  (SND)                       Cayuga Centers
# 3       San Diego  (SND)                       Cayuga Centers
# 4                    NaN                       Cayuga Centers
# ...                  ...                                  ...
# 3165      El Paso  (ELP)                            Homestead
# 3166     Harlingen (SNA)             Southwest Key Casa Padre
# 3167  Phoenix, AZ  (PHO)  Bethany Christian Services Maryland
# 3168    San Diego  (SND)              Southwest Key San Diego
# 3169  Phoenix, AZ  (PHO)                    BCFS Raymondville
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0     Discharged Under other approp circumstances  DISCHARGED        7/8/2018
# 1     Discharged Under other approp circumstances  DISCHARGED        6/4/2018
# 2     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 3     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 4     Discharged Under other approp circumstances  DISCHARGED       11/7/2018
# ...                                           ...         ...             ...
# 3165                                Still In Care    ADMITTED             NaN
# 3166                  Other approp. Circumstances  DISCHARGED       3/21/2019
# 3167                    Reunited with Sep. Parent  DISCHARGED       3/15/2019
# 3168                    Reunited with Sep. Parent  DISCHARGED        1/8/2019
# 3169                                Still In Care    ADMITTED             NaN
#
#                           Reason fo Separation        lat        lon
# 0                        Zero Tolerance Policy  41.889183 -87.632519
# 1                        Zero Tolerance Policy          0          0
# 2                        Zero Tolerance Policy    40.8088    73.9307
# 3                        Zero Tolerance Policy    40.8088    73.9307
# 4                        Zero Tolerance Policy    40.8088    73.9307
# ...                                        ...        ...        ...
# 3165                   Parent Criminal History          0          0
# 3166                   Parent Criminal History   25.94322  -97.42408
# 3167                                     Other  38.989371 -76.692933
# 3168                     Adult Relative‐ Other          0          0
# 3169  Unable to verify familial\nrelationship.  26.451811 -97.798278
#
# [3170 rows x 14 columns]

# %%
facilities_df = df.groupby(by=["FACILITY_APPROVED", "lat", "lon"]).size().to_frame('count').reset_index()
display(facilities_df)
# Out:
#                 FACILITY_APPROVED        lat         lon  count
# 0   A New Leaf – Dorothy Mitchell  33.422445 -111.794883      5
# 1           A New Leaf – Peterson  33.422445 -111.794883      5
# 2            Abbott House Shelter  41.044318  -73.859016     26
# 3                Abbott House TFC  41.043934  -73.858957      3
# 4                    BCFS Baytown  29.784163  -95.056497     62
# ..                            ...        ...         ...    ...
# 95                    St. PJs TFC  29.389160  -98.492685     15
# 96                   The Villages   0.000000    0.000000     14
# 97                        Upbring  29.672296  -98.502569     35
# 98             Youth For Tomorrow  38.739783  -77.549131     22
# 99                      Youthcare  47.668293 -122.299840      8
#
# [100 rows x 4 columns]

# %%
facilities_df.head(10).to_csv('mapbox_test_data.csv', index=False)

# %%
import plotly.graph_objects as go

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_us_cities.csv')
df.head()

df['text'] = df['name'] + '<br>Population ' + (df['pop']/1e6).astype(str)+' million'
limits = [(0,2),(3,10),(11,20),(21,50),(50,3000)]
colors = ["#C70039", "#FFC300","#FF5733","#900C3E", "#571845"]
cities = []
scale = 5000

fig = go.Figure()

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    fig.add_trace(go.Scattergeo(
        locationmode = 'USA-states',
        lon = df_sub['lon'],
        lat = df_sub['lat'],
        text = df_sub['text'],
        marker = dict(
            size = df_sub['pop']/scale,
            color = colors[i],
            line_color='rgb(40,40,40)',
            line_width=0.5,
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1])))

fig.update_layout(
        title_text = 'WHERE ARE THE CHILDREN?',
        showlegend = True,
        geo = dict(
            scope = 'usa',
            landcolor = "#bababa",
        bgcolor="#161616"
        )
    )

fig.show()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1273             raise CannotSendHeader()
# -> 1274         self._send_output(message_body, encode_chunked=encode_chunked)
#    1275
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1033         del self._buffer[:]
# -> 1034         self.send(msg)
#    1035
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in connect(self)
#    1447
# -> 1448             self.sock = self._context.wrap_socket(self.sock,
#    1449                                                   server_hostname=server_hostname)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /var/folders/vn/skw3dlhd3y79vqz8w4rvqf000000gn/T/ipykernel_20395/1449525916.py in <module>
#       3 import pandas as pd
#       4
# ----> 5 df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_us_cities.csv')
#       6 df.head()
#       7
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     607
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#     611         encoding=encoding,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     310         # assuming storage_options is to be interpreted as headers
#     311         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 312         with urlopen(req_info) as req:
#     313             content_encoding = req.headers.get("Content-Encoding", None)
#     314             if content_encoding == "gzip":
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     210     import urllib.request
#     211
# --> 212     return urllib.request.urlopen(*args, **kwargs)
#     213
#     214
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>

# %%
import plotly.graph_objects as go

import pandas as pd

df = facilities_df 
df['text'] = df['FACILITY_APPROVED']+ " : "+ (df['count']).astype(str)+ ' children'
df = df.sort_values(by = ['count'])

#df.head(10)

limits = [(0,10),(11,25),(26,50),(50,100)]
colors = ["#C70039", "#FFC300","#FF5733","#900C3E", "#571845"]

df_sub = df[lim[0]:lim[1]]

# display(df_sub)

fig = go.Figure()

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    fig.add_trace(go.Scattergeo(
        locationmode = 'USA-states',
        lon = df_sub['lon'],
        lat = df_sub['lat'],
        text = df_sub['text'],
        marker = dict(
            size = df_sub['count'],
            color = colors[i],
            line_color='rgb(40,40,40)',
            line_width=0.5,
            sizemode = 'area',
            sizeref=2.*100/(40.**2),
        ),
        name = '{0} - {1}'.format(lim[0],lim[1])))

fig.update_layout(
        showlegend = True,
        geo = dict(
            scope = 'usa',
            landcolor = "#bababa",
            bgcolor='rgba(0,0,0,0)',
        ),
        paper_bgcolor='rgba(0,0,0,0)',
        plot_bgcolor='rgba(0,0,0,0)'
    )
fig.update_layout(
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="right",
        x=0.99,
        font=dict(color='rgb(230, 230, 230)'),
        ),
    )

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vn/skw3dlhd3y79vqz8w4rvqf000000gn/T/ipykernel_20395/207251992.py in <module>
#      12 colors = ["#C70039", "#FFC300","#FF5733","#900C3E", "#571845"]
#      13
# ---> 14 df_sub = df[lim[0]:lim[1]]
#      15
#      16 # display(df_sub)
#
# NameError: name 'lim' is not defined

# %%
# Exporting to HTML
fig.write_html('../map.html')

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv ("separation_data_set.csv")
df["lat"] = ""
df["lon"] = ""

display(df)
# Out:
#      AGE GENDER          COO DATE_APPREHENDED REFERRAL_DATE DATE_ORR_APPROVED  \
# 0     16      M       Brazil        2/15/2018     2/15/2018         2/17/2018
# 1     17      F      Romania        5/27/2018     5/29/2018         5/30/2018
# 2     11      M       Mexico         2/1/2018      2/6/2018          2/8/2018
# 3     15      M       Mexico         2/2/2018      2/6/2018          2/8/2018
# 4      8      M     Honduras         6/2/2018      6/4/2018          6/5/2018
# ...   ..    ...          ...              ...           ...               ...
# 3165  14      M    Guatemala        1/28/2019     1/30/2019          2/1/2019
# 3166  17      M    Guatemala        1/14/2019     1/16/2019         1/16/2019
# 3167   1      F  El Salvador       12/10/2018    12/12/2018        12/14/2018
# 3168  16      M    Guatemala        12/6/2018      1/2/2019          1/3/2019
# 3169   9      M    Guatemala       12/16/2018    12/19/2018        12/22/2018
#
#         REFERRING OFFICE                    FACILITY_APPROVED  \
# 0         El Paso  (ELP)          Heartland Intl Childrens RC
# 1        Harlingen (SNA)                            Homestead
# 2       San Diego  (SND)                       Cayuga Centers
# 3       San Diego  (SND)                       Cayuga Centers
# 4                    NaN                       Cayuga Centers
# ...                  ...                                  ...
# 3165      El Paso  (ELP)                            Homestead
# 3166     Harlingen (SNA)             Southwest Key Casa Padre
# 3167  Phoenix, AZ  (PHO)  Bethany Christian Services Maryland
# 3168    San Diego  (SND)              Southwest Key San Diego
# 3169  Phoenix, AZ  (PHO)                    BCFS Raymondville
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0     Discharged Under other approp circumstances  DISCHARGED        7/8/2018
# 1     Discharged Under other approp circumstances  DISCHARGED        6/4/2018
# 2     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 3     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 4     Discharged Under other approp circumstances  DISCHARGED       11/7/2018
# ...                                           ...         ...             ...
# 3165                                Still In Care    ADMITTED             NaN
# 3166                  Other approp. Circumstances  DISCHARGED       3/21/2019
# 3167                    Reunited with Sep. Parent  DISCHARGED       3/15/2019
# 3168                    Reunited with Sep. Parent  DISCHARGED        1/8/2019
# 3169                                Still In Care    ADMITTED             NaN
#
#                           Reason fo Separation lat lon
# 0                        Zero Tolerance Policy
# 1                        Zero Tolerance Policy
# 2                        Zero Tolerance Policy
# 3                        Zero Tolerance Policy
# 4                        Zero Tolerance Policy
# ...                                        ...  ..  ..
# 3165                   Parent Criminal History
# 3166                   Parent Criminal History
# 3167                                     Other
# 3168                     Adult Relative‐ Other
# 3169  Unable to verify familial\nrelationship.
#
# [3170 rows x 14 columns]

# %%
facilities_df = df.groupby(by=["FACILITY_APPROVED"]).size().to_frame('count').reset_index()

# %%
shelter_dict = {
    'Heartland Intl Childrens RC' : (41.889183, -87.632519),
    'Cayuga Centers' : (40.8088, -73.9307),
    # Homestead was a temporary shelter
    'Homestead' : (0,0),
    'Southwest Key Las Palmas' : (33.434662, -111.840591),
    'Southwest Key Campbell' : (33.501260, -112.115390),
    'Southwest Key Casa Padre' : (25.943220, -97.424080),
    'A New Leaf – Dorothy Mitchell': (33.42312583690492, -111.79475465271236),
    # Southwest Key Hacienda del Sol
    'Southwest Key Sol': (33.59771115911375, -112.30353218770304),
    'Southwest Key Casa Kokopelli' : (33.41057000348104, -111.81485200053244),
    'Southwest Key Estrella' :(32.241632, -110.97948),
    'The Villages' : (39.057085480413406, -95.78697096777489),
    'A New Leaf – Peterson' : (33.422090, -111.810910),
    'Heartland Guadalupe' :(0,0), 
    'BCFS San Antonio TFC' :(29.489023513806092, -98.5685671455097),
    'Morrison Downtown' :(45.55889871413686, -122.5491566354091),
    'Southwest Key Mesa Shelter': (33.434651870935085, -111.84098673115726), 
    'LSS of New York TFC' :(40.81396993020305, -73.9664686138336),
    'Board of Child Care TFC': (38.49329657584188, -76.7675310422091), 
    'Bethany Christian Services TFC': (0,0),
    'Leake and Watts TFC':(40.69217204490131, -73.98591825255677),
    'Nuevo Amanecer LCS':(34.28755910934501, -118.43619217796676), 
    'Bokenkamp TFC':(27.7177065686254, -97.34968717809491),
    'Southwest Key Casa Phoenix':(33.43648884057369, -112.08148486867414), 
    'BCFS Extended Care':(0,0),
    'BCFS Chavaneaux':(29.321531760534477, -98.52796822690473),
    'H':(0,0), 
    'Southwest Key Canutillo':(31.90807037763406, -106.59511040483042),
    'His House':(25.956392771561816, -80.27980225773756),
    'Catholic Charities Boystown':(26.160271563841256, -80.12750692556861), 
    'International Christian Adoptions':(33.51632724911393, -117.16524905777466),
    'Southwest Key Antigua': (26.123897, -97.632978),
    'St. PJs Childrens Home':(29.389510605840876, -98.49270134222061),
    'Southwest Key Casa Montezuma': (29.774397, -95.145021),
    'Southwest Key Conroe':(30.371544, -95.512041),
    'Southwest Key El Presidente':(25.944447, -97.450052), 
    'Southwest Key Combes':(26.239331, -97.729311),
    'Heartland CHAP':(0,0), 
    'Shiloh Treatment Center':(29.519127294074426, -95.35235029118338),
    'Southwest Key Rio Grande':(26.136415111921824, -97.6220972781903), 
    'Bethany Christian Services Shelter':(0,0),
    'Youth For Tomorrow':(38.73978262834332, -77.54913090432463),
    'Catholic Guardian Services TFC':(40.758022803328025, -73.96387644917374),
    'Childrens Village Shelter':(40.86712278967711, -73.89302256434361), 
    'Southwest Key Casa Lighthouse':(33.48223657383026, -112.05129575847694),
    'MercyFirst':(40.82190315799205, -73.48837767356392),
    'Bethany Christian Services Maryland':(38.98937137244992, -76.69293258909268),
    'BCFS Baytown':(29.784162841517396, -95.05649672675278),
    'CC Houston':(29.74586233145037, -95.37880105283553),
    'David and Margaret':(34.10275439771937, -117.78526757637746),
    'Southwest Key Nueva Esperanza':(26.022101482987534, -97.4265115439823), 
    'Holy Family Institute':(40.51085747804056, -80.0988190796778),
    'Southwest Key Casa Quetzal':(29.867513, -95.407907),
    'Abbott House Shelter':(41.04460969347108, -73.85903753173923),
    'Rite of Passage ‐ Sycamore':(32.53846327994423, -110.71758452433525), 
    'KidsPeace':(40.596270487855485, -75.40668221092272),
    'Crittenton Shelter':(33.875025172927295, -117.91111291569258),
    'Southwest Key Glendale':(33.542104, -112.169822),
    'LSS of New York':(40.81083639084717, -73.96400573997549),
    'Heartland Intl Childrens Center':(41.88621532425004, -87.62569283046726),
    'Bokenkamp':(27.71790130420733, -97.34967108875165),
    'Rite of Passage ‐ Canyon':(39.02370722608039, -119.74993309546248), 
    'LSSS New Hope':(26.210123491244904, -98.21048473254535),
    # Southwest Key El Cajon
    'Southwest Key San Diego': (32.807801, -116.937924), 
    'Board of Child Care Shelter':(39.346900872776, -76.76049583255488), 
    'Noank':(41.35492631454048, -72.08294644215162),
    'BCFS Harlingen': (26.190327116846483, -97.6776081421415),
    'SWK Processing Center':(25.90576557331528, -97.50259119860246), 
    'BCFS Raymondville':(26.451811397813433, -97.79827777339452),
    'Upbring':(31.802536523580358, -106.39747593121628), 
    'Childrens Home of Kingston':(41.92485519650927, -73.97117177341138),
    'Southwest Key Casita Del Valle':(31.5319521, -106.2326139),
    'Southwest Key Casa Franklin':(31.762054, -106.487845),
    'Southwest Key Casa Houston':(29.6909001, -95.4089882),
    'Catholic Guardian Services Crotona':(40.85313762030175, -73.88384835892722),
    'Center for Family Services Shelter':(39.94073661213475, -75.11795520203565),
    'CC Fort Worth Shelter':(32.68354219483105, -97.32727386355151),
    'BCFS San Antonio':(29.489023513806092, -98.5685671455097), 
    'LSS Carolinas TFC':(35.653487891677926, -80.48559843567813),
    'Leake and Watts': (40.69217204490131, -73.98591825255677),
    'Southwest Key Casa Blanca':(29.705200, -98.495848), 
    'BCFS Fairfield':(38.27196592144918, -122.05016687950611), 
    'JCCA':(41.129272265170066, -73.77766517339191),
    'Lincoln Hall Boys Haven':(41.3201108125575, -73.72065523631649), 
    'Maryville Academy': (42.06716651238874, -87.89736113623661),
    'St. PJs TFC': (29.38916001522818, -98.49268524637117),
    'Youthcare':(47.66829272090686, -122.2998400444896), 
    'Seton Home':(29.38871764021308, -98.49104224214504), 
    'Southwest Key Pleasant Hill':(29.38871764021308, -98.49104224214504),
    'Catholic Guardian Services':(40.880516052246094, -73.89922332763672),
    'IES Brownsville':(26.0718647, -97.4763276), 
    'IES Los Fresnos':(26.07855987548828, -97.47564697265625),
    'IES Harlingen':(26.184149965124526, -97.73859872658379), 
    'David and Margaret LTFC':(34.10275439771937, -117.78526757637746), 
    'CHSI San Benito':(26.132187, -97.628685),
    'BCFS Driscoll':(27.789972, -97.654548), 
    'CHSI Los Fresnos': (26.129432678222656, -97.47114562988281), 
    'BCFS Tornillo': (31.464328, -106.169116),
    'CC Fort Worth TFC':(40.741895, -73.989308), 
    'CHSI Casa Norma Linda':(26.075903730505722, -97.52940599545984),
    'Abbott House TFC':(41.04460969347108, -73.859037531739236)
    
}


for shelter in shelter_dict.keys():
    #print(shelter)
    df.loc[df['FACILITY_APPROVED'] == shelter, 'lat'] = shelter_dict[shelter][0]
    df.loc[df['FACILITY_APPROVED'] == shelter, 'lon'] = shelter_dict[shelter][1]

display(df)
# Out:
#      AGE GENDER          COO DATE_APPREHENDED REFERRAL_DATE DATE_ORR_APPROVED  \
# 0     16      M       Brazil        2/15/2018     2/15/2018         2/17/2018
# 1     17      F      Romania        5/27/2018     5/29/2018         5/30/2018
# 2     11      M       Mexico         2/1/2018      2/6/2018          2/8/2018
# 3     15      M       Mexico         2/2/2018      2/6/2018          2/8/2018
# 4      8      M     Honduras         6/2/2018      6/4/2018          6/5/2018
# ...   ..    ...          ...              ...           ...               ...
# 3165  14      M    Guatemala        1/28/2019     1/30/2019          2/1/2019
# 3166  17      M    Guatemala        1/14/2019     1/16/2019         1/16/2019
# 3167   1      F  El Salvador       12/10/2018    12/12/2018        12/14/2018
# 3168  16      M    Guatemala        12/6/2018      1/2/2019          1/3/2019
# 3169   9      M    Guatemala       12/16/2018    12/19/2018        12/22/2018
#
#         REFERRING OFFICE                    FACILITY_APPROVED  \
# 0         El Paso  (ELP)          Heartland Intl Childrens RC
# 1        Harlingen (SNA)                            Homestead
# 2       San Diego  (SND)                       Cayuga Centers
# 3       San Diego  (SND)                       Cayuga Centers
# 4                    NaN                       Cayuga Centers
# ...                  ...                                  ...
# 3165      El Paso  (ELP)                            Homestead
# 3166     Harlingen (SNA)             Southwest Key Casa Padre
# 3167  Phoenix, AZ  (PHO)  Bethany Christian Services Maryland
# 3168    San Diego  (SND)              Southwest Key San Diego
# 3169  Phoenix, AZ  (PHO)                    BCFS Raymondville
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0     Discharged Under other approp circumstances  DISCHARGED        7/8/2018
# 1     Discharged Under other approp circumstances  DISCHARGED        6/4/2018
# 2     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 3     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 4     Discharged Under other approp circumstances  DISCHARGED       11/7/2018
# ...                                           ...         ...             ...
# 3165                                Still In Care    ADMITTED             NaN
# 3166                  Other approp. Circumstances  DISCHARGED       3/21/2019
# 3167                    Reunited with Sep. Parent  DISCHARGED       3/15/2019
# 3168                    Reunited with Sep. Parent  DISCHARGED        1/8/2019
# 3169                                Still In Care    ADMITTED             NaN
#
#                           Reason fo Separation      lat      lon
# 0                        Zero Tolerance Policy  41.8892 -87.6325
# 1                        Zero Tolerance Policy        0        0
# 2                        Zero Tolerance Policy  40.8088 -73.9307
# 3                        Zero Tolerance Policy  40.8088 -73.9307
# 4                        Zero Tolerance Policy  40.8088 -73.9307
# ...                                        ...      ...      ...
# 3165                   Parent Criminal History        0        0
# 3166                   Parent Criminal History  25.9432 -97.4241
# 3167                                     Other  38.9894 -76.6929
# 3168                     Adult Relative‐ Other  32.8078 -116.938
# 3169  Unable to verify familial\nrelationship.  26.4518 -97.7983
#
# [3170 rows x 14 columns]

# %%
shelter_names = {
    'Heartland Intl Childrens RC' : "Heartland International Children’s Reception Center",
    'Cayuga Centers' : "Cayuga Centers",
    # Homestead was a temporary shelter
    'Homestead' : "Homestead",
    'Southwest Key Las Palmas' : 'Southwest Key - Las Palmas',
    'Southwest Key Campbell' : 'Southwest Key - Campbell',
    'Southwest Key Casa Padre' : 'Southwest Key - Casa Padre',
    'A New Leaf – Dorothy Mitchell': "A New Leaf – Dorothy B. Mitchell Counseling Center",
    # Southwest Key Hacienda del Sol
    'Southwest Key Sol': 'Southwest Key - Hacienda del Sol',
    'Southwest Key Casa Kokopelli' : 'Southwest Key - Casa Kokopelli',
    'Southwest Key Estrella' : 'Southwest Key - Estrella del Norte',
    'The Villages' : "The Villages",
    'A New Leaf – Peterson' : "A New Leaf – Alice Peterson Residence",
    'Heartland Guadalupe' : "Heartland Alliance - Casa Guadalupe", 
    'BCFS San Antonio TFC' : "BCFS - San Antonio Transitional Foster Care",
    'Morrison Downtown' : "Morrison Child & Family Services Downtown Shelter",
    'Southwest Key Mesa Shelter': "Southwest Key - Mesa", 
    'LSS of New York TFC' : "Lutheran Social Services of New York Safe Haven for Children",
    'Board of Child Care TFC': "Board of Child Care - Treatment Foster Care", 
    'Bethany Christian Services TFC': "Bethany Christian Services Transitional Foster Care",
    'Leake and Watts TFC': "Rising Ground",
    'Nuevo Amanecer LCS':"Nuevo Amanecer Latino Children Services", 
    'Bokenkamp TFC':"Bokenkamp Children’s Shelter",
    'Southwest Key Casa Phoenix':"Southwest Key - Casa Phoenix", 
    'BCFS Extended Care':"BCFS - Extended Care",
    'BCFS Chavaneaux':"BCFS - Chavaneaux",
    'H':"H", 
    'Southwest Key Canutillo': "Southwest Key - Canutillo",
    'His House':"His House Children’s Home",
    'Catholic Charities Boystown':"Catholic Charities - Msgr. Bryan Walsh Children’s Village", 
    'International Christian Adoptions':"International Christian Adoptions",
    'Southwest Key Antigua': 'Southwest Key - Antigua',
    'St. PJs Childrens Home':"St. Peter-St. Joseph Children’s Home",
    'Southwest Key Casa Montezuma': "Southwest Key - Casa Montezuma",
    'Southwest Key Conroe':"Southwest Key - Conroe",
    'Southwest Key El Presidente':"Southwest Key - El Presidente", 
    'Southwest Key Combes': "Southwest Key - Combes)",
    'Heartland CHAP':"Heartland - CHAP", 
    'Shiloh Treatment Center':"Shiloh Treatment Center",
    'Southwest Key Rio Grande': "Southwest Key - Rio Grande", 
    'Bethany Christian Services Shelter':"Bethany Christian Services",
    'Youth For Tomorrow': "Youth for Tomorrow",
    'Catholic Guardian Services TFC':"Catholic Guardian Services - Transitional Foster Care",
    'Childrens Village Shelter':"Children’s Village Shelter", 
    'Southwest Key Casa Lighthouse':"Southwest Key - Casa Lighthouse",
    'MercyFirst':"MercyFirst",
    'Bethany Christian Services Maryland':"Bethany Christian Services TFC - Baltimore",
    'BCFS Baytown':"BCFS Baytown",
    'CC Houston': "Catholic Charities - Houston",
    'David and Margaret':"David and Margaret Youth and Family Services",
    'Southwest Key Nueva Esperanza':"Southwest Key - Nueva Esperanza", 
    'Holy Family Institute': "Holy Family Institute",
    'Southwest Key Casa Quetzal': "Southwest Key - Casa Quetzal",
    'Abbott House Shelter':"Abbott House",
    'Rite of Passage ‐ Sycamore':"Rite of Passage - Sycamore", 
    'KidsPeace':"KidsPeace Broadway Campus",
    'Crittenton Shelter':"Crittenton Services for Children and Families",
    'Southwest Key Glendale':"Southwest Key - Glendale",
    'LSS of New York': "Lutheran Social Services of New York Safe Haven for Children",
    'Heartland Intl Childrens Center':"Heartland International Children’s Center",
    'Bokenkamp':"Bokenkamp Children’s Shelter",
    'Rite of Passage ‐ Canyon':'Rite of Passage ‐ Canyon', 
    'LSSS New Hope':"Upbring New Hope Children’s Center",
    # Southwest Key El Cajon
    'Southwest Key San Diego': "Southwest Key - San Diego'", 
    'Board of Child Care Shelter': "Board of Child Care Shelter", 
    'Noank':'Noank',
    'BCFS Harlingen': "BCFS - Harlingen",
    'SWK Processing Center': "Southwest Key - Processing Center", 
    'BCFS Raymondville':"BCFS - Raymondville",
    'Upbring':"Upbring Transitional Foster Care program in El Paso", 
    'Childrens Home of Kingston':"Children’s Home of Kingston",
    'Southwest Key Casita Del Valle': "Southwest Key - Casita del Valle",
    'Southwest Key Casa Franklin': "Southwest Key - Casa Franklin",
    'Southwest Key Casa Houston':"Southwest Key - Casa Franklin",
    'Catholic Guardian Services Crotona':"Catholic Guardian Services - Crotrona",
    'Center for Family Services Shelter':"Center for Family Services",
    'CC Fort Worth Shelter':"Catholic Charities - Fort Worth",
    'BCFS San Antonio':"BCFS - San Antonio", 
    'LSS Carolinas TFC':"Lutheran Social Services of Carolinas - Transitional Foster Care",
    'Leake and Watts': "Rising Ground",
    'Southwest Key Casa Blanca': "Southwest Key - Casa Blanca", 
    'BCFS Fairfield': "BCFS - Fairfield", 
    'JCCA':"JCCA",
    'Lincoln Hall Boys Haven': "Lincoln Hall Boys’ Haven", 
    'Maryville Academy': "Maryville Academy",
    'St. PJs TFC':"St. Peter-St. Joseph Children’s Home - Transitional Foster Care",
    'Youthcare':"YouthCare", 
    'Seton Home':"Seton Home", 
    'Southwest Key Pleasant Hill':"Southwest Key - Pleasant Hill",
    'Catholic Guardian Services': "Catholic Guardian Services",
    'IES Brownsville': "IES - Brownsville", 
    'IES Los Fresnos':'IES - Los Fresnos',
    'IES Harlingen':'IES - Harlingen', 
    'David and Margaret LTFC':"David and Margaret Youth and Family Services", 
    'CHSI San Benito': "CHSI - San Benito",
    'BCFS Driscoll':'BCFS - Driscoll', 
    'CHSI Los Fresnos': "CHSI - Los Fresnos", 
    'BCFS Tornillo': 'BCFS - Tornillo',
    'CC Fort Worth TFC':"Catholic Charities Fort Worth Transitional Foster Care", 
    'CHSI Casa Norma Linda':"CHSI - Casa Norma Linda",
    'Abbott House TFC':"Abbott House"
    
}


for name in shelter_dict.keys():
    #print(shelter)
    df.loc[df['FACILITY_APPROVED'] == name, 'FACILITY_APPROVED'] = shelter_names[name]

display(df)
# Out:
#      AGE GENDER          COO DATE_APPREHENDED REFERRAL_DATE DATE_ORR_APPROVED  \
# 0     16      M       Brazil        2/15/2018     2/15/2018         2/17/2018
# 1     17      F      Romania        5/27/2018     5/29/2018         5/30/2018
# 2     11      M       Mexico         2/1/2018      2/6/2018          2/8/2018
# 3     15      M       Mexico         2/2/2018      2/6/2018          2/8/2018
# 4      8      M     Honduras         6/2/2018      6/4/2018          6/5/2018
# ...   ..    ...          ...              ...           ...               ...
# 3165  14      M    Guatemala        1/28/2019     1/30/2019          2/1/2019
# 3166  17      M    Guatemala        1/14/2019     1/16/2019         1/16/2019
# 3167   1      F  El Salvador       12/10/2018    12/12/2018        12/14/2018
# 3168  16      M    Guatemala        12/6/2018      1/2/2019          1/3/2019
# 3169   9      M    Guatemala       12/16/2018    12/19/2018        12/22/2018
#
#         REFERRING OFFICE                                  FACILITY_APPROVED  \
# 0         El Paso  (ELP)  Heartland International Children’s Reception C...
# 1        Harlingen (SNA)                                          Homestead
# 2       San Diego  (SND)                                     Cayuga Centers
# 3       San Diego  (SND)                                     Cayuga Centers
# 4                    NaN                                     Cayuga Centers
# ...                  ...                                                ...
# 3165      El Paso  (ELP)                                          Homestead
# 3166     Harlingen (SNA)                         Southwest Key - Casa Padre
# 3167  Phoenix, AZ  (PHO)         Bethany Christian Services TFC - Baltimore
# 3168    San Diego  (SND)                         Southwest Key - San Diego'
# 3169  Phoenix, AZ  (PHO)                                BCFS - Raymondville
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0     Discharged Under other approp circumstances  DISCHARGED        7/8/2018
# 1     Discharged Under other approp circumstances  DISCHARGED        6/4/2018
# 2     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 3     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 4     Discharged Under other approp circumstances  DISCHARGED       11/7/2018
# ...                                           ...         ...             ...
# 3165                                Still In Care    ADMITTED             NaN
# 3166                  Other approp. Circumstances  DISCHARGED       3/21/2019
# 3167                    Reunited with Sep. Parent  DISCHARGED       3/15/2019
# 3168                    Reunited with Sep. Parent  DISCHARGED        1/8/2019
# 3169                                Still In Care    ADMITTED             NaN
#
#                           Reason fo Separation      lat      lon
# 0                        Zero Tolerance Policy  41.8892 -87.6325
# 1                        Zero Tolerance Policy        0        0
# 2                        Zero Tolerance Policy  40.8088 -73.9307
# 3                        Zero Tolerance Policy  40.8088 -73.9307
# 4                        Zero Tolerance Policy  40.8088 -73.9307
# ...                                        ...      ...      ...
# 3165                   Parent Criminal History        0        0
# 3166                   Parent Criminal History  25.9432 -97.4241
# 3167                                     Other  38.9894 -76.6929
# 3168                     Adult Relative‐ Other  32.8078 -116.938
# 3169  Unable to verify familial\nrelationship.  26.4518 -97.7983
#
# [3170 rows x 14 columns]

# %%
# delete rows with where lat + lon are (0,0)
df = df.loc[(df["lat"] != 0)].reset_index()
display(df)
# Out:
#       index AGE GENDER          COO DATE_APPREHENDED REFERRAL_DATE  \
# 0         0  16      M       Brazil        2/15/2018     2/15/2018
# 1         2  11      M       Mexico         2/1/2018      2/6/2018
# 2         3  15      M       Mexico         2/2/2018      2/6/2018
# 3         4   8      M     Honduras         6/2/2018      6/4/2018
# 4         5   4      M    Guatemala        6/15/2018     6/18/2018
# ...     ...  ..    ...          ...              ...           ...
# 2842   3164  16      F  El Salvador        3/12/2019     3/15/2019
# 2843   3166  17      M    Guatemala        1/14/2019     1/16/2019
# 2844   3167   1      F  El Salvador       12/10/2018    12/12/2018
# 2845   3168  16      M    Guatemala        12/6/2018      1/2/2019
# 2846   3169   9      M    Guatemala       12/16/2018    12/19/2018
#
#      DATE_ORR_APPROVED    REFERRING OFFICE  \
# 0            2/17/2018      El Paso  (ELP)
# 1             2/8/2018    San Diego  (SND)
# 2             2/8/2018    San Diego  (SND)
# 3             6/5/2018                 NaN
# 4            6/20/2018      El Paso  (ELP)
# ...                ...                 ...
# 2842         3/17/2019  Phoenix, AZ  (PHO)
# 2843         1/16/2019     Harlingen (SNA)
# 2844        12/14/2018  Phoenix, AZ  (PHO)
# 2845          1/3/2019    San Diego  (SND)
# 2846        12/22/2018  Phoenix, AZ  (PHO)
#
#                                       FACILITY_APPROVED  \
# 0     Heartland International Children’s Reception C...
# 1                                        Cayuga Centers
# 2                                        Cayuga Centers
# 3                                        Cayuga Centers
# 4                                        Cayuga Centers
# ...                                                 ...
# 2842                            Southwest Key - Antigua
# 2843                         Southwest Key - Casa Padre
# 2844         Bethany Christian Services TFC - Baltimore
# 2845                         Southwest Key - San Diego'
# 2846                                BCFS - Raymondville
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0     Discharged Under other approp circumstances  DISCHARGED        7/8/2018
# 1     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 2     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 3     Discharged Under other approp circumstances  DISCHARGED       11/7/2018
# 4                        Reunited with Sep Parent  DISCHARGED       7/11/2018
# ...                                           ...         ...             ...
# 2842                                Still In Care    ADMITTED             NaN
# 2843                  Other approp. Circumstances  DISCHARGED       3/21/2019
# 2844                    Reunited with Sep. Parent  DISCHARGED       3/15/2019
# 2845                    Reunited with Sep. Parent  DISCHARGED        1/8/2019
# 2846                                Still In Care    ADMITTED             NaN
#
#                           Reason fo Separation      lat      lon
# 0                        Zero Tolerance Policy  41.8892 -87.6325
# 1                        Zero Tolerance Policy  40.8088 -73.9307
# 2                        Zero Tolerance Policy  40.8088 -73.9307
# 3                        Zero Tolerance Policy  40.8088 -73.9307
# 4                        Zero Tolerance Policy  40.8088 -73.9307
# ...                                        ...      ...      ...
# 2842                   Parent Criminal History  26.1239  -97.633
# 2843                   Parent Criminal History  25.9432 -97.4241
# 2844                                     Other  38.9894 -76.6929
# 2845                     Adult Relative‐ Other  32.8078 -116.938
# 2846  Unable to verify familial\nrelationship.  26.4518 -97.7983
#
# [2847 rows x 15 columns]

# %%
df = df.drop('index', axis=1)
display(df)
# Out:
#      AGE GENDER          COO DATE_APPREHENDED REFERRAL_DATE DATE_ORR_APPROVED  \
# 0     16      M       Brazil        2/15/2018     2/15/2018         2/17/2018
# 1     11      M       Mexico         2/1/2018      2/6/2018          2/8/2018
# 2     15      M       Mexico         2/2/2018      2/6/2018          2/8/2018
# 3      8      M     Honduras         6/2/2018      6/4/2018          6/5/2018
# 4      4      M    Guatemala        6/15/2018     6/18/2018         6/20/2018
# ...   ..    ...          ...              ...           ...               ...
# 2842  16      F  El Salvador        3/12/2019     3/15/2019         3/17/2019
# 2843  17      M    Guatemala        1/14/2019     1/16/2019         1/16/2019
# 2844   1      F  El Salvador       12/10/2018    12/12/2018        12/14/2018
# 2845  16      M    Guatemala        12/6/2018      1/2/2019          1/3/2019
# 2846   9      M    Guatemala       12/16/2018    12/19/2018        12/22/2018
#
#         REFERRING OFFICE                                  FACILITY_APPROVED  \
# 0         El Paso  (ELP)  Heartland International Children’s Reception C...
# 1       San Diego  (SND)                                     Cayuga Centers
# 2       San Diego  (SND)                                     Cayuga Centers
# 3                    NaN                                     Cayuga Centers
# 4         El Paso  (ELP)                                     Cayuga Centers
# ...                  ...                                                ...
# 2842  Phoenix, AZ  (PHO)                            Southwest Key - Antigua
# 2843     Harlingen (SNA)                         Southwest Key - Casa Padre
# 2844  Phoenix, AZ  (PHO)         Bethany Christian Services TFC - Baltimore
# 2845    San Diego  (SND)                         Southwest Key - San Diego'
# 2846  Phoenix, AZ  (PHO)                                BCFS - Raymondville
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0     Discharged Under other approp circumstances  DISCHARGED        7/8/2018
# 1     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 2     Discharged Under other approp circumstances  DISCHARGED        2/2/2019
# 3     Discharged Under other approp circumstances  DISCHARGED       11/7/2018
# 4                        Reunited with Sep Parent  DISCHARGED       7/11/2018
# ...                                           ...         ...             ...
# 2842                                Still In Care    ADMITTED             NaN
# 2843                  Other approp. Circumstances  DISCHARGED       3/21/2019
# 2844                    Reunited with Sep. Parent  DISCHARGED       3/15/2019
# 2845                    Reunited with Sep. Parent  DISCHARGED        1/8/2019
# 2846                                Still In Care    ADMITTED             NaN
#
#                           Reason fo Separation      lat      lon
# 0                        Zero Tolerance Policy  41.8892 -87.6325
# 1                        Zero Tolerance Policy  40.8088 -73.9307
# 2                        Zero Tolerance Policy  40.8088 -73.9307
# 3                        Zero Tolerance Policy  40.8088 -73.9307
# 4                        Zero Tolerance Policy  40.8088 -73.9307
# ...                                        ...      ...      ...
# 2842                   Parent Criminal History  26.1239  -97.633
# 2843                   Parent Criminal History  25.9432 -97.4241
# 2844                                     Other  38.9894 -76.6929
# 2845                     Adult Relative‐ Other  32.8078 -116.938
# 2846  Unable to verify familial\nrelationship.  26.4518 -97.7983
#
# [2847 rows x 14 columns]

# %%
facilities_df = df.groupby(by=["FACILITY_APPROVED", "lat", "lon"]).size().to_frame('count').reset_index()
display(facilities_df)
# Out:
#                                     FACILITY_APPROVED        lat         lon  \
# 0               A New Leaf – Alice Peterson Residence  33.422090 -111.810910
# 1   A New Leaf – Dorothy B. Mitchell Counseling Ce...  33.423126 -111.794755
# 2                                        Abbott House  41.044610  -73.859038
# 3                                   BCFS - Chavaneaux  29.321532  -98.527968
# 4                                     BCFS - Driscoll  27.789972  -97.654548
# ..                                                ...        ...         ...
# 85                                       The Villages  39.057085  -95.786971
# 86                 Upbring New Hope Children’s Center  26.210123  -98.210485
# 87  Upbring Transitional Foster Care program in El...  31.802537 -106.397476
# 88                                 Youth for Tomorrow  38.739783  -77.549131
# 89                                          YouthCare  47.668293 -122.299840
#
#     count
# 0       5
# 1       5
# 2      29
# 3      26
# 4       6
# ..    ...
# 85     14
# 86     11
# 87     35
# 88     22
# 89      8
#
# [90 rows x 4 columns]

# %%
from datetime import datetime

def days_between(d1, d2):
    d1 = datetime.strptime(d1, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%Y-%m-%d")
    return abs((d2 - d1).days)


start = df["DATE_APPREHENDED"]
end = df["Date Discharged"]


duration_col = []

for i in range(len(df)):
    d1 = start[i]
    d2 = end[i]
    
    if type(d2) == float or len(d2)<5:
        duration_col.append(0)
    else:
        split1 = d1.split("/")
       
        date1 = split1[2] + "-" + split1[0]+"-" + split1[1]
        

        split2 = d2.split("/")
        date2 = split2[2] + "-" + split2[0]+"-" + split2[1]
    
        dur = days_between(date1,date2)
        
        duration_col.append(dur)
        
df_new = df.assign(Duration = duration_col)

df_new['DATE_APPREHENDED'] = pd.to_datetime(df_new['DATE_APPREHENDED'])
df_new = df_new.sort_values(by='DATE_APPREHENDED')


display(df_new)
# Out:
#      AGE GENDER        COO DATE_APPREHENDED REFERRAL_DATE DATE_ORR_APPROVED  \
# 2163  13      F  Guatemala       2018-01-01      1/2/2018          1/3/2018
# 2167   1      M  Guatemala       2018-01-02      1/3/2018          1/3/2018
# 2176  11      M  Guatemala       2018-01-05      1/5/2018          1/6/2018
# 2166  10      F      Congo       2018-01-10     1/10/2018         1/12/2018
# 2230  10      M  Guatemala       2018-01-10     1/11/2018         1/12/2018
# ...   ..    ...        ...              ...           ...               ...
# 2829   0      M  Guatemala       2019-03-15     3/18/2019         3/19/2019
# 2813  12      M  Guatemala       2019-03-15     3/17/2019         3/18/2019
# 2809   7      F  Guatemala       2019-03-15     3/17/2019         3/19/2019
# 2832  11      M  Guatemala       2019-03-15     3/18/2019         3/19/2019
# 2810   5      F  Guatemala       2019-03-15     3/17/2019         3/19/2019
#
#         REFERRING OFFICE                                  FACILITY_APPROVED  \
# 2163    San Diego  (SND)                   Southwest Key - Hacienda del Sol
# 2167        Laredo (LRD)                                  IES - Brownsville
# 2176  Phoenix, AZ  (PHO)                       Southwest Key - Casa Phoenix
# 2166        Laredo (LRD)  Heartland International Children’s Reception C...
# 2230     Harlingen (SNA)                                  IES - Los Fresnos
# ...                  ...                                                ...
# 2829     Harlingen (SNA)                                 CHSI - Los Fresnos
# 2813       Del Rio (DRO)  Lutheran Social Services of New York Safe Have...
# 2809  Phoenix, AZ  (PHO)  Lutheran Social Services of New York Safe Have...
# 2832     Harlingen (SNA)                                     Cayuga Centers
# 2810                 NaN                            Southwest Key - Combes)
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 2163                                Still in Care    ADMITTED             NaN
# 2167                     Reunited with Sep Parent  DISCHARGED       3/14/2018
# 2176                     Reunited with Sep Parent  DISCHARGED       9/20/2018
# 2166  Discharged Under other approp circumstances  DISCHARGED        9/8/2018
# 2230                     Reunited with Sep Parent  DISCHARGED       3/19/2018
# ...                                           ...         ...             ...
# 2829                                Still In Care    ADMITTED             NaN
# 2813                                Still In Care    ADMITTED             NaN
# 2809                                Still In Care    ADMITTED             NaN
# 2832                                Still In Care    ADMITTED             NaN
# 2810                                Still In Care    ADMITTED             NaN
#
#          Reason fo Separation      lat      lon  Duration
# 2163    Zero Tolerance Policy  33.5977 -112.304         0
# 2167    Zero Tolerance Policy  26.0719 -97.4763        71
# 2176    Zero Tolerance Policy  33.4365 -112.081       258
# 2166    Zero Tolerance Policy  41.8892 -87.6325       241
# 2230    Zero Tolerance Policy  26.0786 -97.4756        68
# ...                       ...      ...      ...       ...
# 2829  Parent Criminal History  26.1294 -97.4711         0
# 2813  Parent Criminal History   40.814 -73.9665         0
# 2809  Parent Criminal History   40.814 -73.9665         0
# 2832  Parent Criminal History  40.8088 -73.9307         0
# 2810  Parent Criminal History  26.2393 -97.7293         0
#
# [2847 rows x 15 columns]

# %%
# calculate the avg durationa across ALL children:
df_avg = df_new.loc[(df_new["Duration"] != 0)]#.reset_index()
#df_avg.drop(['index'])
display(df_avg)
# Out:
#      AGE GENDER        COO DATE_APPREHENDED REFERRAL_DATE DATE_ORR_APPROVED  \
# 2167   1      M  Guatemala       2018-01-02      1/3/2018          1/3/2018
# 2176  11      M  Guatemala       2018-01-05      1/5/2018          1/6/2018
# 2166  10      F      Congo       2018-01-10     1/10/2018         1/12/2018
# 2230  10      M  Guatemala       2018-01-10     1/11/2018         1/12/2018
# 2172  13      M  Guatemala       2018-01-10     1/11/2018         1/11/2018
# ...   ..    ...        ...              ...           ...               ...
# 2788   7      M  Guatemala       2019-02-27      3/1/2019          3/2/2019
# 2795   6      M  Guatemala       2019-03-02      3/4/2019          3/5/2019
# 2815   6      M  Guatemala       2019-03-05      3/9/2019         3/10/2019
# 2784   6      M  Guatemala       2019-03-06      3/7/2019          3/8/2019
# 2841  17      M  Guatemala       2019-03-09     3/12/2019         3/14/2019
#
#         REFERRING OFFICE                                  FACILITY_APPROVED  \
# 2167        Laredo (LRD)                                  IES - Brownsville
# 2176  Phoenix, AZ  (PHO)                       Southwest Key - Casa Phoenix
# 2166        Laredo (LRD)  Heartland International Children’s Reception C...
# 2230     Harlingen (SNA)                                  IES - Los Fresnos
# 2172  Phoenix, AZ  (PHO)                       Southwest Key - Casa Phoenix
# ...                  ...                                                ...
# 2788     Harlingen (SNA)                                BCFS - Raymondville
# 2795     Harlingen (SNA)                                     Cayuga Centers
# 2815     Harlingen (SNA)                                     Cayuga Centers
# 2784   San Antonio (SNA)        BCFS - San Antonio Transitional Foster Care
# 2841  Phoenix, AZ  (PHO)                         Children’s Village Shelter
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 2167                     Reunited with Sep Parent  DISCHARGED       3/14/2018
# 2176                     Reunited with Sep Parent  DISCHARGED       9/20/2018
# 2166  Discharged Under other approp circumstances  DISCHARGED        9/8/2018
# 2230                     Reunited with Sep Parent  DISCHARGED       3/19/2018
# 2172                     Reunited with Sep Parent  DISCHARGED       10/3/2018
# ...                                           ...         ...             ...
# 2788                  Other approp. Circumstances  DISCHARGED       3/25/2019
# 2795                  Other approp. Circumstances  DISCHARGED       3/23/2019
# 2815                  Other approp. Circumstances  DISCHARGED       3/27/2019
# 2784                  Other approp. Circumstances  DISCHARGED       3/28/2019
# 2841                  Other approp. Circumstances  DISCHARGED       3/29/2019
#
#                                    Reason fo Separation      lat      lon  \
# 2167                              Zero Tolerance Policy  26.0719 -97.4763
# 2176                              Zero Tolerance Policy  33.4365 -112.081
# 2166                              Zero Tolerance Policy  41.8892 -87.6325
# 2230                              Zero Tolerance Policy  26.0786 -97.4756
# 2172                              Zero Tolerance Policy  33.4365 -112.081
# ...                                                 ...      ...      ...
# 2788  Parent has Criminal history (US or Home\nCountry)  26.4518 -97.7983
# 2795             Parent Immigration\nProsecution (1326)  40.8088 -73.9307
# 2815                            Parent Criminal History  40.8088 -73.9307
# 2784  Parent has Criminal history (US or Home\nCountry)   29.489 -98.5686
# 2841                            Parent Criminal History  40.8671  -73.893
#
#       Duration
# 2167        71
# 2176       258
# 2166       241
# 2230        68
# 2172       266
# ...        ...
# 2788        26
# 2795        21
# 2815        22
# 2784        22
# 2841        20
#
# [2664 rows x 15 columns]

# %%
df_new.to_csv('arc_data.csv')

# %%
h = df_new[["FACILITY_APPROVED", "UAC STATUS"]].copy()
discharge_binary = []
for i in h["UAC STATUS"]:
    if i == "DISCHARGED":
        discharge_binary.append(1)
    else:
        discharge_binary.append(0)
        
df_discharge = pd.DataFrame({'discharge_rate':discharge_binary})

df_discharge_rate = h.join(df_discharge).groupby(["FACILITY_APPROVED"]).mean()
display(df_discharge_rate)
# Out:
#                                                     discharge_rate
# FACILITY_APPROVED
# A New Leaf – Alice Peterson Residence                     1.000000
# A New Leaf – Dorothy B. Mitchell Counseling Center        1.000000
# Abbott House                                              0.965517
# BCFS - Chavaneaux                                         1.000000
# BCFS - Driscoll                                           0.500000
# ...                                                            ...
# The Villages                                              1.000000
# Upbring New Hope Children’s Center                        1.000000
# Upbring Transitional Foster Care program in El ...        0.914286
# Youth for Tomorrow                                        1.000000
# YouthCare                                                 1.000000
#
# [87 rows x 1 columns]

# %%
df_n = df_new[["FACILITY_APPROVED", "lat", "lon","Duration"]].copy()
display(df_n)
# Out:
#                                       FACILITY_APPROVED      lat      lon  \
# 2163                   Southwest Key - Hacienda del Sol  33.5977 -112.304
# 2167                                  IES - Brownsville  26.0719 -97.4763
# 2176                       Southwest Key - Casa Phoenix  33.4365 -112.081
# 2166  Heartland International Children’s Reception C...  41.8892 -87.6325
# 2230                                  IES - Los Fresnos  26.0786 -97.4756
# ...                                                 ...      ...      ...
# 2829                                 CHSI - Los Fresnos  26.1294 -97.4711
# 2813  Lutheran Social Services of New York Safe Have...   40.814 -73.9665
# 2809  Lutheran Social Services of New York Safe Have...   40.814 -73.9665
# 2832                                     Cayuga Centers  40.8088 -73.9307
# 2810                            Southwest Key - Combes)  26.2393 -97.7293
#
#       Duration
# 2163         0
# 2167        71
# 2176       258
# 2166       241
# 2230        68
# ...        ...
# 2829         0
# 2813         0
# 2809         0
# 2832         0
# 2810         0
#
# [2847 rows x 4 columns]

# %%
df_avg_duration = df_n.groupby(["FACILITY_APPROVED"]).mean()

# %%
map_df = df_avg_duration.join(df_discharge_rate)
display(map_df)
# Out:
#                                                      Duration  discharge_rate
# FACILITY_APPROVED
# A New Leaf – Alice Peterson Residence               51.200000        1.000000
# A New Leaf – Dorothy B. Mitchell Counseling Center  63.600000        1.000000
# Abbott House                                        70.689655        0.965517
# BCFS - Chavaneaux                                   61.153846        1.000000
# BCFS - Driscoll                                     31.666667        0.500000
# ...                                                       ...             ...
# The Villages                                        66.857143        1.000000
# Upbring New Hope Children’s Center                  70.090909        1.000000
# Upbring Transitional Foster Care program in El ...  67.457143        0.914286
# Youth for Tomorrow                                  54.681818        1.000000
# YouthCare                                           85.625000        1.000000
#
# [87 rows x 2 columns]

# %%
map_df = pd.merge(facilities_df, map_df, on="FACILITY_APPROVED")
display(map_df)
# Out:
#                                     FACILITY_APPROVED        lat         lon  \
# 0               A New Leaf – Alice Peterson Residence  33.422090 -111.810910
# 1   A New Leaf – Dorothy B. Mitchell Counseling Ce...  33.423126 -111.794755
# 2                                        Abbott House  41.044610  -73.859038
# 3                                   BCFS - Chavaneaux  29.321532  -98.527968
# 4                                     BCFS - Driscoll  27.789972  -97.654548
# ..                                                ...        ...         ...
# 85                                       The Villages  39.057085  -95.786971
# 86                 Upbring New Hope Children’s Center  26.210123  -98.210485
# 87  Upbring Transitional Foster Care program in El...  31.802537 -106.397476
# 88                                 Youth for Tomorrow  38.739783  -77.549131
# 89                                          YouthCare  47.668293 -122.299840
#
#     count   Duration  discharge_rate
# 0       5  51.200000        1.000000
# 1       5  63.600000        1.000000
# 2      29  70.689655        0.965517
# 3      26  61.153846        1.000000
# 4       6  31.666667        0.500000
# ..    ...        ...             ...
# 85     14  66.857143        1.000000
# 86     11  70.090909        1.000000
# 87     35  67.457143        0.914286
# 88     22  54.681818        1.000000
# 89      8  85.625000        1.000000
#
# [90 rows x 6 columns]

# %%
map_df["Duration"].unique()
# Out:
# array([ 51.2       ,  63.6       ,  70.68965517,  61.15384615,
#         31.66666667, 296.        ,  51.71153846,  49.33333333,
#         48.28571429,  74.89814815,  41.        ,  75.9516129 ,
#         85.33333333, 101.66666667,  79.7       ,  71.03571429,
#         24.625     ,  62.83333333,  38.8       ,  56.        ,
#         79.66666667,  51.86206897,  38.66666667,  45.6       ,
#         61.5       ,  65.92307692,  76.9144385 ,  77.5       ,
#         47.71428571,  78.13043478,  66.31818182,  44.42857143,
#         88.42857143,  72.93023256,  54.39393939,  80.26315789,
#         71.        ,  66.        ,  68.        ,  72.83333333,
#          0.        ,  68.5       ,  64.41666667,  45.42857143,
#         59.02272727,  50.33333333,  74.57894737,  61.        ,
#         49.5       ,  63.35294118,  66.02941176,  84.57142857,
#         85.25      ,  32.        ,  50.66666667,  70.67088608,
#         70.        ,  74.16      , 102.5       ,  69.64705882,
#         95.41538462,  66.4375    ,  73.38461538,  77.89754098,
#         71.47619048,  69.25581395,  87.1       ,  56.78651685,
#         71.52272727,  59.32876712,  69.27368421,  61.31818182,
#         87.03636364, 106.86666667,  79.5       ,  54.47169811,
#         36.        ,  63.35714286,  61.10638298,  67.        ,
#         74.11111111,  40.        ,  66.85714286,  70.09090909,
#         67.45714286,  54.68181818,  85.625     ])

# %%
mean = map_df["Duration"].mean()
std = map_df["Duration"].std()

print(mean)
print(std)

conditions = [
    (map_df['Duration'] < mean - std ),
    (map_df['Duration'] >= mean - std) & (map_df['Duration'] <= mean + std),
    (map_df['Duration'] > mean + std)
    ]

values = ['low', 'average', 'high']

map_df['status'] = np.select(conditions, values)

display(map_df)
# Out:
# 67.31389588215019
# 29.873274691588342
#                                     FACILITY_APPROVED        lat         lon  \
# 0               A New Leaf – Alice Peterson Residence  33.422090 -111.810910
# 1   A New Leaf – Dorothy B. Mitchell Counseling Ce...  33.423126 -111.794755
# 2                                        Abbott House  41.044610  -73.859038
# 3                                   BCFS - Chavaneaux  29.321532  -98.527968
# 4                                     BCFS - Driscoll  27.789972  -97.654548
# ..                                                ...        ...         ...
# 85                                       The Villages  39.057085  -95.786971
# 86                 Upbring New Hope Children’s Center  26.210123  -98.210485
# 87  Upbring Transitional Foster Care program in El...  31.802537 -106.397476
# 88                                 Youth for Tomorrow  38.739783  -77.549131
# 89                                          YouthCare  47.668293 -122.299840
#
#     count   Duration  discharge_rate   status
# 0       5  51.200000        1.000000  average
# 1       5  63.600000        1.000000  average
# 2      29  70.689655        0.965517  average
# 3      26  61.153846        1.000000  average
# 4       6  31.666667        0.500000      low
# ..    ...        ...             ...      ...
# 85     14  66.857143        1.000000  average
# 86     11  70.090909        1.000000  average
# 87     35  67.457143        0.914286  average
# 88     22  54.681818        1.000000  average
# 89      8  85.625000        1.000000  average
#
# [90 rows x 7 columns]

# %%
map_df.groupby(by=["status"]).size()
# Out:
# status
# average    81
# high        4
# low         5
# dtype: int64

# %%
map_df.to_csv('map_data.csv')

# %%
map_df = pd.merge(facilities_df, df_discharge_rate, on="FACILITY_APPROVED")
map_df["discharge_rate"] = round(map_df["discharge_rate"]*100)
display(map_df)
# Out:
#                                     FACILITY_APPROVED        lat         lon  \
# 0               A New Leaf – Alice Peterson Residence  33.422090 -111.810910
# 1   A New Leaf – Dorothy B. Mitchell Counseling Ce...  33.423126 -111.794755
# 2                                        Abbott House  41.044610  -73.859038
# 3                                   BCFS - Chavaneaux  29.321532  -98.527968
# 4                                     BCFS - Driscoll  27.789972  -97.654548
# ..                                                ...        ...         ...
# 85                                       The Villages  39.057085  -95.786971
# 86                 Upbring New Hope Children’s Center  26.210123  -98.210485
# 87  Upbring Transitional Foster Care program in El...  31.802537 -106.397476
# 88                                 Youth for Tomorrow  38.739783  -77.549131
# 89                                          YouthCare  47.668293 -122.299840
#
#     count  discharge_rate
# 0       5           100.0
# 1       5           100.0
# 2      29           100.0
# 3      26           100.0
# 4       6            33.0
# ..    ...             ...
# 85     14           100.0
# 86     11           100.0
# 87     35            89.0
# 88     22            95.0
# 89      8           100.0
#
# [90 rows x 5 columns]

# %%
map_df.to_csv('map_data.csv')

# %%
# get data for forced bubble chart:
df_new["groupid"] = ""
df_new["size"] = 174
df_new.reset_index(level=0, inplace=True)
display(df_new)
# Out:
#       index AGE GENDER        COO DATE_APPREHENDED REFERRAL_DATE  \
# 0      2163  13      F  Guatemala       2018-01-01      1/2/2018
# 1      2167   1      M  Guatemala       2018-01-02      1/3/2018
# 2      2176  11      M  Guatemala       2018-01-05      1/5/2018
# 3      2166  10      F      Congo       2018-01-10     1/10/2018
# 4      2230  10      M  Guatemala       2018-01-10     1/11/2018
# ...     ...  ..    ...        ...              ...           ...
# 2842   2829   0      M  Guatemala       2019-03-15     3/18/2019
# 2843   2813  12      M  Guatemala       2019-03-15     3/17/2019
# 2844   2809   7      F  Guatemala       2019-03-15     3/17/2019
# 2845   2832  11      M  Guatemala       2019-03-15     3/18/2019
# 2846   2810   5      F  Guatemala       2019-03-15     3/17/2019
#
#      DATE_ORR_APPROVED    REFERRING OFFICE  \
# 0             1/3/2018    San Diego  (SND)
# 1             1/3/2018        Laredo (LRD)
# 2             1/6/2018  Phoenix, AZ  (PHO)
# 3            1/12/2018        Laredo (LRD)
# 4            1/12/2018     Harlingen (SNA)
# ...                ...                 ...
# 2842         3/19/2019     Harlingen (SNA)
# 2843         3/18/2019       Del Rio (DRO)
# 2844         3/19/2019  Phoenix, AZ  (PHO)
# 2845         3/19/2019     Harlingen (SNA)
# 2846         3/19/2019                 NaN
#
#                                       FACILITY_APPROVED  \
# 0                      Southwest Key - Hacienda del Sol
# 1                                     IES - Brownsville
# 2                          Southwest Key - Casa Phoenix
# 3     Heartland International Children’s Reception C...
# 4                                     IES - Los Fresnos
# ...                                                 ...
# 2842                                 CHSI - Los Fresnos
# 2843  Lutheran Social Services of New York Safe Have...
# 2844  Lutheran Social Services of New York Safe Have...
# 2845                                     Cayuga Centers
# 2846                            Southwest Key - Combes)
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0                                   Still in Care    ADMITTED             NaN
# 1                        Reunited with Sep Parent  DISCHARGED       3/14/2018
# 2                        Reunited with Sep Parent  DISCHARGED       9/20/2018
# 3     Discharged Under other approp circumstances  DISCHARGED        9/8/2018
# 4                        Reunited with Sep Parent  DISCHARGED       3/19/2018
# ...                                           ...         ...             ...
# 2842                                Still In Care    ADMITTED             NaN
# 2843                                Still In Care    ADMITTED             NaN
# 2844                                Still In Care    ADMITTED             NaN
# 2845                                Still In Care    ADMITTED             NaN
# 2846                                Still In Care    ADMITTED             NaN
#
#          Reason fo Separation      lat      lon  Duration groupid  size
# 0       Zero Tolerance Policy  33.5977 -112.304         0           174
# 1       Zero Tolerance Policy  26.0719 -97.4763        71           174
# 2       Zero Tolerance Policy  33.4365 -112.081       258           174
# 3       Zero Tolerance Policy  41.8892 -87.6325       241           174
# 4       Zero Tolerance Policy  26.0786 -97.4756        68           174
# ...                       ...      ...      ...       ...     ...   ...
# 2842  Parent Criminal History  26.1294 -97.4711         0           174
# 2843  Parent Criminal History   40.814 -73.9665         0           174
# 2844  Parent Criminal History   40.814 -73.9665         0           174
# 2845  Parent Criminal History  40.8088 -73.9307         0           174
# 2846  Parent Criminal History  26.2393 -97.7293         0           174
#
# [2847 rows x 18 columns]

# %%
sep_reason_dict = {
    
    'Zero Tolerance Policy': ('Zero Tolerance Policy', 0) , 
    'Parent has Criminal\nHistory':('Parent Criminal History', 1),
    'Gang\nMembership/Affiliation' : ('Gang Membership or Affiliation', 2),
    'Parent has Criminal\nhistory (US or Home Country)': ('Parent Criminal History', 1),
    'Parent has health\nissues/hospitalized': ('Parent Health Issues or Hospitalization', 3),
    'Parent has Criminal history (US or Home\nCountry)': ('Parent Criminal History', 1),
    'Parent has cartel/gang\naffiliation': ('Gang Membership or Affiliation', 2),
    'Parent has Criminal history (US or Home Country); gang affiliation; sent for immigration\nprosecution' : ('Parent Criminal History', 1),
    'Parent has Criminal history (US or Home Country);gang affiliation; gang affilatiion; sent for\nimmigraiton proseuction': ('Parent Criminal History', 1),
    'Parenthood not verifiable': ('Other', 4),
    'Parent has cartel/gang affiliation; sent for immigration prosecution.':('Gang Membership or Affiliation', 2),
    'Criminal History':('Parent Criminal History', 1),
    'Parent has both Criminal & Immigration history charges (US/Home\nCountry)':('Parent has both Criminal and Immigration Charges', 5),
    'Parent has criminal\nhistory (US/Home Country); sent for prosecution.': ('Parent Criminal History', 1),
    'Parent has both Criminal & Immigration history charges (US/Home Country); sent for\nproseuction' : ('Parent has both Criminal and Immigration Charges', 5),
    'Parent has Criminal\nhistory charges (US/Home Country); sent for proseuction.': ('Gang Membership or Affiliation', 2),
    'Parent has cartel/gang\naffiliation; criminal history.': ('Gang Membership or Affiliation', 2),
    'Parent has Criminal history (US or Home Country); parent has\ncartel/gang affiliation.': ('Parent Criminal History', 1),
    'Has cartel/gang\naffiliation.': ('Parent Immigration History', 6),
    'Sent for immigration\nprosecution' : ('Parent Immigration History', 6), 
    'Criminal': ('Parent Criminal History', 1),
    'Parent has criminal\nhistory': ('Parent Criminal History', 1),
    'Parent has Criminal\nhistory (US or Home Country); sent for immigration prosecution': ('Parent Criminal History', 1),
    'Other': ('Other', 4), 
    'Was sent for immigration prosecution.': ('Parent Immigration History', 6),
    'Parent has both Criminal\n& Immigration history charges (US/Home Country)': ('Parent has both Criminal and Immigration Charges', 5),
    'Child Safety': ("Other", 4), 
    'Gang': ('Gang Membership or Affiliation', 2),
    'Parent has Criminal history (US or Home Country); sent for\nimmigration prosecution': ('Parent Criminal History', 1),
    'Parent has Criminal history charges (US/Home Country); sent for immigration proseuction.': ('Parent Criminal History', 1),
    'Gang affiliation/gang\nmembership': ('Gang Membership or Affiliation', 2),
    'Criminal History; sent for\nimmigration prosecution': ('Parent Immigration History', 6),
    'Other (Please explain under Additional\nInformation column)': ("Other", 4),
    'Parent has Criminal history charges (US/Home\nCountry)': ('Parent Criminal History', 1),
    'Parent has Criminal\nhistory charges (US/Home Country)': ('Parent Criminal History', 1),
    'Child safety': ("Other", 4),
    'Immigration History Only': ('Parent Immigration History', 6),
    'Parent has Criminal\nhistory; sent for immigration prosecution': ('Parent Criminal History', 1),
    'Unable to verify familial\nrelationship.':("Other", 4), 
    'Placement into FRC as FAMU, after legal guardianship was verified.' :("Other", 4), 
    'Parent has both Criminal charges (US/Home Country) and was sent for immigration prosecution.': ('Parent Criminal History', 1) ,
    'Immigration history only' : ("Parent Immigration History", 6), 
    'Parent has Criminal\nhistory' : ('Parent Criminal History', 1),
    'Parent has criminal history (US/Home Country); sent for immigration prosecution.': ('Parent Criminal History', 1),
    'Sent for immigration\nprosecution.': ("Parent Immigration History", 6),
    'Parent has Criminal\nhistory charges (US/Home Country); cartel/gang affiliation.': ('Parent Criminal History', 1),
    'Sent for prosecution': ("Parent Immigration History", 6),
    'Parent has cartel/gang affiliation; criminal\nhistory.': ('Gang Membership or Affiliation', 2),
    'Has cartel/gang affiliation; sent for immigration prosecution.': ('Gang Membership or Affiliation', 2),
    'Parent has Criminal\nHistory (US/Home Country); sent for immigration prosecution': ('Parent Criminal History', 1),
    'Parent has Criminal history (US or Home Country) and gang\naffiliation': ('Parent Criminal History', 1),
    'Parent has cartel/gang affiliation; sent for\nprosecution': ('Gang Membership or Affiliation', 2),
    'Parent has cartel/gang\naffiliation; sent for prosecution' : ('Gang Membership or Affiliation', 2),
    'Parent has Criminal history (US or Home Country); sent for\nimmigraiton prosecution':('Parent Criminal History', 1) ,
    'Other (Please explain\nunder Additional Information column)': ('Other', 4), 
    'Sent for  immigration\nprosecution': ('Parent Immigration History', 6),
    'Parent Immigration\nProsecution (1326)':('Parent Immigration History', 6), 
    'Hospitalization': ('Parent Health Issues or Hospitalization', 3),
    'Unverified Familial\nRelationship': ('Other', 4), 
    'Parent Criminal History': ('Parent Criminal History', 1),
    'Parent Immigration\nProsecution (Other)': ('Parent Immigration History', 6),
    'Adult Relative‐ Other' :('Other', 4)
 
   
}




for reason in sep_reason_dict.keys():
    #print(shelter
    #print(reason)
    #print(df.loc[df_new['Reason fo Separation'] == reason])
    df_new.loc[df_new['Reason fo Separation'] == reason, 'groupid'] = round(sep_reason_dict[reason][1])
    df_new.loc[df_new['Reason fo Separation'] == reason, 'Reason fo Separation'] = sep_reason_dict[reason][0]
    

display(df_new)
# Out:
#       index AGE GENDER        COO DATE_APPREHENDED REFERRAL_DATE  \
# 0      2163  13      F  Guatemala       2018-01-01      1/2/2018
# 1      2167   1      M  Guatemala       2018-01-02      1/3/2018
# 2      2176  11      M  Guatemala       2018-01-05      1/5/2018
# 3      2166  10      F      Congo       2018-01-10     1/10/2018
# 4      2230  10      M  Guatemala       2018-01-10     1/11/2018
# ...     ...  ..    ...        ...              ...           ...
# 2842   2829   0      M  Guatemala       2019-03-15     3/18/2019
# 2843   2813  12      M  Guatemala       2019-03-15     3/17/2019
# 2844   2809   7      F  Guatemala       2019-03-15     3/17/2019
# 2845   2832  11      M  Guatemala       2019-03-15     3/18/2019
# 2846   2810   5      F  Guatemala       2019-03-15     3/17/2019
#
#      DATE_ORR_APPROVED    REFERRING OFFICE  \
# 0             1/3/2018    San Diego  (SND)
# 1             1/3/2018        Laredo (LRD)
# 2             1/6/2018  Phoenix, AZ  (PHO)
# 3            1/12/2018        Laredo (LRD)
# 4            1/12/2018     Harlingen (SNA)
# ...                ...                 ...
# 2842         3/19/2019     Harlingen (SNA)
# 2843         3/18/2019       Del Rio (DRO)
# 2844         3/19/2019  Phoenix, AZ  (PHO)
# 2845         3/19/2019     Harlingen (SNA)
# 2846         3/19/2019                 NaN
#
#                                       FACILITY_APPROVED  \
# 0                      Southwest Key - Hacienda del Sol
# 1                                     IES - Brownsville
# 2                          Southwest Key - Casa Phoenix
# 3     Heartland International Children’s Reception C...
# 4                                     IES - Los Fresnos
# ...                                                 ...
# 2842                                 CHSI - Los Fresnos
# 2843  Lutheran Social Services of New York Safe Have...
# 2844  Lutheran Social Services of New York Safe Have...
# 2845                                     Cayuga Centers
# 2846                            Southwest Key - Combes)
#
#                             REUNITIED_SEP_PARENTS  UAC STATUS Date Discharged  \
# 0                                   Still in Care    ADMITTED             NaN
# 1                        Reunited with Sep Parent  DISCHARGED       3/14/2018
# 2                        Reunited with Sep Parent  DISCHARGED       9/20/2018
# 3     Discharged Under other approp circumstances  DISCHARGED        9/8/2018
# 4                        Reunited with Sep Parent  DISCHARGED       3/19/2018
# ...                                           ...         ...             ...
# 2842                                Still In Care    ADMITTED             NaN
# 2843                                Still In Care    ADMITTED             NaN
# 2844                                Still In Care    ADMITTED             NaN
# 2845                                Still In Care    ADMITTED             NaN
# 2846                                Still In Care    ADMITTED             NaN
#
#          Reason fo Separation      lat      lon  Duration groupid  size
# 0       Zero Tolerance Policy  33.5977 -112.304         0       0   174
# 1       Zero Tolerance Policy  26.0719 -97.4763        71       0   174
# 2       Zero Tolerance Policy  33.4365 -112.081       258       0   174
# 3       Zero Tolerance Policy  41.8892 -87.6325       241       0   174
# 4       Zero Tolerance Policy  26.0786 -97.4756        68       0   174
# ...                       ...      ...      ...       ...     ...   ...
# 2842  Parent Criminal History  26.1294 -97.4711         0       1   174
# 2843  Parent Criminal History   40.814 -73.9665         0       1   174
# 2844  Parent Criminal History   40.814 -73.9665         0       1   174
# 2845  Parent Criminal History  40.8088 -73.9307         0       1   174
# 2846  Parent Criminal History  26.2393 -97.7293         0       1   174
#
# [2847 rows x 18 columns]

# %%
df_new.columns
df_new["Reason fo Separation"].unique()
# Out:
# array(['Zero Tolerance Policy', 'Other', 'Gang Membership or Affiliation',
#        'Parent Health Issues or Hospitalization',
#        'Parent has both Criminal and Immigration Charges',
#        'Parent Criminal History', 'Parent Immigration History'],
#       dtype=object)

# %%
df_forced = df_new[['index', 'groupid', 'size', 'Reason fo Separation']].copy()
#display(df_forced)
#df_new.columns

#df_bubble = df_forced.groupby(["Reason fo Separation"]).count()
#display(df_bubble)

display(df_forced)
# Out:
#       index groupid  size     Reason fo Separation
# 0      2163       0   174    Zero Tolerance Policy
# 1      2167       0   174    Zero Tolerance Policy
# 2      2176       0   174    Zero Tolerance Policy
# 3      2166       0   174    Zero Tolerance Policy
# 4      2230       0   174    Zero Tolerance Policy
# ...     ...     ...   ...                      ...
# 2842   2829       1   174  Parent Criminal History
# 2843   2813       1   174  Parent Criminal History
# 2844   2809       1   174  Parent Criminal History
# 2845   2832       1   174  Parent Criminal History
# 2846   2810       1   174  Parent Criminal History
#
# [2847 rows x 4 columns]

# %%
df_bubble = df_forced.groupby(["Reason fo Separation"]).size().to_frame('size')
df_bubble.reset_index(level=0, inplace=True)

df_bubble['groupid'] = ''
df_bubble['index'] = ''

index_dict = {
    
        'Zero Tolerance Policy' : 0, 
        'Other':6, 
        'Gang Membership or Affiliation' : 4,
        'Parent Health Issues or Hospitalization' :5,
        'Parent has both Criminal and Immigration Charges' : 3,
        'Parent Criminal History' : 1, 
        'Parent Immigration History' : 2,   
    
}

for ind in index_dict.keys():
    #print(shelter
    #print(reason)
    #print(df.loc[df_new['Reason fo Separation'] == reason])
    df_bubble.loc[df_bubble['Reason fo Separation'] == ind, 'groupid'] = index_dict[ind]
    df_bubble.loc[df_bubble['Reason fo Separation'] == ind, 'index'] = index_dict[ind]




    

display(df_bubble)
# Out:
#                                Reason fo Separation  size  groupid  index
# 0                    Gang Membership or Affiliation    33        4      4
# 1                                             Other    33        6      6
# 2                           Parent Criminal History   240        1      1
# 3           Parent Health Issues or Hospitalization    20        5      5
# 4                        Parent Immigration History    27        2      2
# 5  Parent has both Criminal and Immigration Charges    18        3      3
# 6                             Zero Tolerance Policy  2476        0      0

# %%
df_forced.to_csv('forced_data.csv')

# %%
df_bubble.to_csv('forced_data.csv')
